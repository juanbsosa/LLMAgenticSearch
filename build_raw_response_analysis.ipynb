# %% [markdown]
# # Build functions to analyze the content of the raw response from the agentic app

# %%
# Import main packages
import pandas as pd
import os

from datetime import datetime
from tqdm import tqdm
import json
import numpy as np


# App package
from llm_agentic_app_for_price_sources import build_df_with_search_result_content, build_df_with_search_terms, search_term_performace, build_df_with_search_results, analytics_report

# Define directories
def find_directory_upwards(dir_name):
    """
    Find the absolute path to a directory with the given name by searching upwards
    from the current notebook's directory.

    Parameters:
    dir_name (str): The name of the directory to find.

    Returns:
    str: The absolute path to the directory if found, otherwise None.
    """
    # Get the current notebook's directory
    current_dir = os.getcwd()
    
    while True:
        # Check if the directory exists in the current directory
        potential_path = os.path.join(current_dir, dir_name)
        if os.path.isdir(potential_path):
            return potential_path
        
        # Move to the parent directory
        parent_dir = os.path.abspath(os.path.join(current_dir, os.pardir))
        
        # If the current directory is the root directory, stop searching
        if current_dir == parent_dir:
            break
        
        current_dir = parent_dir
    
    # If the directory is not found, return None
    return None

code_dir = find_directory_upwards('codes')
raw_data_dir = find_directory_upwards('raw_data')
int_data_dir = find_directory_upwards('int_data')
final_data_dir = find_directory_upwards('final_data')
output_dir = find_directory_upwards('output')

print(code_dir)
# print(raw_data_dir)
print(int_data_dir)
print(output_dir)
# Out:
# /home/sosajuanbautista/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# /home/sosajuanbautista/aeai-filestore/projects/agentic/codes
# /home/sosajuanbautista/aeai-filestore/projects/agentic/int_data
# /home/sosajuanbautista/aeai-filestore/projects/agentic/output

# %% [markdown]
# ## Load a raw response

# %%
path = os.path.join(final_data_dir, 'commodity_price_sources', 'commodity_prices_search_results_evaluated_2024-11-19_12.16.json')
with open(path, 'r') as file:
    raw_responses_commodities = json.load(file)
print(len(raw_responses_commodities))
for entry in raw_responses_commodities:
    print(entry['item_to_search'])
    print(entry.keys())
    print('\n')
# Out:
# 20
# Rotary tiller or power tiller
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Farming excavator
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Mowers
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Track excavators
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Forklifts
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Automobiles or cars
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Battery energy storage control and management system
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Solar power plants
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# General tool kits
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Trim or molding tools
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Gabion block
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Toothbrush or tumbler holder
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Computer server
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Notebook computer
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Desktop computer
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Personal computer
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Photocopiers
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Multifunction machines
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Office product equipment and stationery consumable
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])
#
#
# Inkjet printer for commercial printing applications
# dict_keys(['item_to_search', 'item_type', 'search_results_to_evaluate', 'evaluated_search_results', 'min_approved_search_results', 'include_justification', 'use_raw_content', 'max_content_length', 'min_similarity_score', 'n_refined_search_terms', 'max_results_per_search_term', 'search_terms_temperature_iteration', 'iteration_number', 'max_iterations', 'n_input_tokens', 'n_output_tokens', 'n_tavily_api_calls'])

# %%
path = os.path.join(final_data_dir, 'product_price_sources', 'product_prices_search_results_evaluated_2024-11-18_00.20.json')
with open(path, 'r') as file:
    raw_responses_products = json.load(file)
print(len(raw_responses_products))
for entry in raw_responses_products:
    print(entry['item_to_search'])
    # print(entry.keys())
    # print('\n')
# Out:
# 20
# E-Z-GO RXV Elite Golf Cart
# B. Braun Infusomat Space Infusion Pump
# CLUB CAR DS Golf cart
# Club Car IQ Electric Electric Golf Car
# Yale GC050VX Forklift
# Chevrolet Traverse SUV
# Lenovo ThinkPad T14s G2 Notebook computer
# Ford E-150 Cargo Van
# Kubota LA525 Front Loader
# Intek Strength Pro Steel Dumbbell Pair Dumbbells
# Dell PowerEdge R740 Computer server
# Park Cottage RV Recreational Vehicle
# E-Z-GO RXV-G Golf cart
# Xerox DocuMate 262 Document Scanner
# Chrysler Voyager LX Minivan
# Toyota 8FGCU25 Forklift
# Land Pride BB1260 Box Scraper
# Raymond 740R45TT Reach Forklift
# EZGO TXT PDS Golf Cart
# Land Pride RCR1260 Rotary Cutter

# %%
print(entry['evaluated_search_results'][0].keys())
# Out:
# dict_keys(['title', 'url', 'content', 'score', 'raw_content', 'query', 'evaluation_outcome', 'justification'])

# %%
print(entry['search_terms_temperature_iteration'])
# Out:
# [['Land Pride RCR1260 Rotary Cutter used prices', 0, None], ['Land Pride RCR1260 Rotary Cutter price list', 0, None], ['Land Pride RCR1260 Rotary Cutter blue book', 0, None], ['buy Land Pride RCR1260 Rotary Cutter', 1, 0.3], ['Land Pride RCR1260 Rotary Cutter for sale', 1, 0.3], ['Land Pride RCR1260 Rotary Cutter pricing information', 1, 0.3], ['Land Pride RCR1260 Rotary Cutter price comparison', 2, 0.5], ['Land Pride RCR1260 Rotary Cutter listings', 2, 0.5], ['Land Pride RCR1260 Rotary Cutter for sale near me', 2, 0.5]]

# %% [markdown]
# ## Analysis

# %%
build_df_with_search_result_content(raw_responses_products)
# Out:
#                                                    url  \
# 0                        https://prestigegolfcars.com/
# 1    https://ezgo.txtsv.com/personal/models/freedom...
# 2    https://keweenawmountainlodge.com/wp-content/u...
# 3    https://www.gowithgarretts.com/product/e-z-go-...
# 4    https://www.windtreegolf.com/kelley-blue-book-...
# ..                                                 ...
# 465  https://www.tractorbynet.com/forums/threads/la...
# 466  https://www.machinerypete.com/details/rotary-c...
# 467  https://www.tractorhouse.com/listing/for-sale/...
# 468  https://www.tractorhouse.com/listings/for-sale...
# 469  https://www.johnsontractor.com/inventory/?/lis...
#
#                                            raw_content
# 0    Click Here to view our Golf Cars currently on ...
# 1    Freedom RXV | E-Z-GO®\nSkip to main content\n\...
# 2    UNBEATABLE ENERGY EFFICIENCY MAINTENANCE FREE ...
# 3    E-Z-GO Freedom RXV ELITE Lithium - Go With Gar...
# 4    Kelley Blue Book for Golf Carts? (How to Value...
# ..                                                 ...
# 465                                                NaN
# 466  \nComplete the form below and we'll contact yo...
# 467  LAND PRIDE RCR1260\nSeller Information\nGerman...
# 468                                                NaN
# 469                                                NaN
#
# [470 rows x 2 columns]

# %%
build_df_with_search_terms(raw_responses_products, item_type='product')
# Out:
# /home/sosajuanbautista/aeai-filestore/projects/agentic/codes/price_retrieval/llm_agentic_app_for_price_sources.py:819: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   output_df = pd.concat([output_df, pd.DataFrame({item_type: item, 'iteration': sti[1],
#                               product iteration  temperature  \
# 0          E-Z-GO RXV Elite Golf Cart         0          NaN
# 1          E-Z-GO RXV Elite Golf Cart         0          NaN
# 2          E-Z-GO RXV Elite Golf Cart         0          NaN
# 3          E-Z-GO RXV Elite Golf Cart         1          0.3
# 4          E-Z-GO RXV Elite Golf Cart         1          0.3
# ..                                ...       ...          ...
# 175  Land Pride RCR1260 Rotary Cutter         1          0.3
# 176  Land Pride RCR1260 Rotary Cutter         1          0.3
# 177  Land Pride RCR1260 Rotary Cutter         2          0.5
# 178  Land Pride RCR1260 Rotary Cutter         2          0.5
# 179  Land Pride RCR1260 Rotary Cutter         2          0.5
#
#                                            search_term
# 0                E-Z-GO RXV Elite Golf Cart price list
# 1               E-Z-GO RXV Elite Golf Cart used prices
# 2                 E-Z-GO RXV Elite Golf Cart blue book
# 3                  E-Z-GO RXV Elite Golf Cart for sale
# 4                   E-Z-GO RXV Elite Golf Cart pricing
# ..                                                 ...
# 175          Land Pride RCR1260 Rotary Cutter for sale
# 176  Land Pride RCR1260 Rotary Cutter pricing infor...
# 177  Land Pride RCR1260 Rotary Cutter price comparison
# 178          Land Pride RCR1260 Rotary Cutter listings
# 179  Land Pride RCR1260 Rotary Cutter for sale near me
#
# [180 rows x 4 columns]

# %%
# build_df_with_search_results(raw_responses_commodities).head()
build_df_with_search_results(raw_responses_products, item_type='product').head()
# Out:
#                       product                           search_term  \
# 0  E-Z-GO RXV Elite Golf Cart  E-Z-GO RXV Elite Golf Cart blue book
# 1  E-Z-GO RXV Elite Golf Cart  E-Z-GO RXV Elite Golf Cart blue book
# 2  E-Z-GO RXV Elite Golf Cart  E-Z-GO RXV Elite Golf Cart blue book
# 3  E-Z-GO RXV Elite Golf Cart  E-Z-GO RXV Elite Golf Cart blue book
# 4  E-Z-GO RXV Elite Golf Cart  E-Z-GO RXV Elite Golf Cart blue book
#
#                                                title  \
# 0  Prestige Golf Cars | Golf Cart Dealer in Murri...
# 1                              Freedom RXV | E-Z-GO®
# 2                                                PDF
# 3  E-Z-GO Freedom RXV ELITE Lithium - Go With Gar...
# 4  Kelley Blue Book for Golf Carts? (How to Value...
#
#                                                  url  evaluation_outcome  \
# 0                      https://prestigegolfcars.com/                True
# 1  https://ezgo.txtsv.com/personal/models/freedom...                True
# 2  https://keweenawmountainlodge.com/wp-content/u...               False
# 3  https://www.gowithgarretts.com/product/e-z-go-...                True
# 4  https://www.windtreegolf.com/kelley-blue-book-...               False
#
#                                        justification
# 0  The webpage is from a golf cart dealer and inc...
# 1  The webpage provides a starting MSRP of $8,674...
# 2  The search result is a PDF document containing...
# 3  The webpage provides a product listing for the...
# 4  The search result provides general information...

# %%
search_term_performace(raw_responses_products, item_type='product')
# Out:
# /home/sosajuanbautista/aeai-filestore/projects/agentic/codes/price_retrieval/llm_agentic_app_for_price_sources.py:819: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   output_df = pd.concat([output_df, pd.DataFrame({item_type: item, 'iteration': sti[1],
#                               product iteration  temperature  \
# 0          E-Z-GO RXV Elite Golf Cart         0          NaN
# 1          E-Z-GO RXV Elite Golf Cart         0          NaN
# 2          E-Z-GO RXV Elite Golf Cart         0          NaN
# 3          E-Z-GO RXV Elite Golf Cart         1          0.3
# 4          E-Z-GO RXV Elite Golf Cart         1          0.3
# ..                                ...       ...          ...
# 175  Land Pride RCR1260 Rotary Cutter         1          0.3
# 176  Land Pride RCR1260 Rotary Cutter         1          0.3
# 177  Land Pride RCR1260 Rotary Cutter         2          0.5
# 178  Land Pride RCR1260 Rotary Cutter         2          0.5
# 179  Land Pride RCR1260 Rotary Cutter         2          0.5
#
#                                            search_term  \
# 0                E-Z-GO RXV Elite Golf Cart price list
# 1               E-Z-GO RXV Elite Golf Cart used prices
# 2                 E-Z-GO RXV Elite Golf Cart blue book
# 3                  E-Z-GO RXV Elite Golf Cart for sale
# 4                   E-Z-GO RXV Elite Golf Cart pricing
# ..                                                 ...
# 175          Land Pride RCR1260 Rotary Cutter for sale
# 176  Land Pride RCR1260 Rotary Cutter pricing infor...
# 177  Land Pride RCR1260 Rotary Cutter price comparison
# 178          Land Pride RCR1260 Rotary Cutter listings
# 179  Land Pride RCR1260 Rotary Cutter for sale near me
#
#      evaluated_searchs_results  approved_search_results  \
# 0                          4.0                      3.0
# 1                          5.0                      5.0
# 2                          5.0                      3.0
# 3                          3.0                      3.0
# 4                          3.0                      3.0
# ..                         ...                      ...
# 175                        3.0                      3.0
# 176                        2.0                      2.0
# 177                        3.0                      2.0
# 178                        2.0                      2.0
# 179                        1.0                      1.0
#
#      disapproved_search_results
# 0                           1.0
# 1                           0.0
# 2                           2.0
# 3                           0.0
# 4                           0.0
# ..                          ...
# 175                         0.0
# 176                         0.0
# 177                         1.0
# 178                         0.0
# 179                         0.0
#
# [180 rows x 7 columns]

# %%
# search_term_performace(raw_responses_commodities).to_csv(os.path.join(final_data_dir, 'commodity_price_sources', 'search_term_performance.csv'), index=False)

# %%
# analytics_report(raw_responses_commodities, item_type='commodity')
analytics_report(raw_responses_products, item_type='product')
# Out:
# /home/sosajuanbautista/aeai-filestore/projects/agentic/codes/price_retrieval/llm_agentic_app_for_price_sources.py:819: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   output_df = pd.concat([output_df, pd.DataFrame({item_type: item, 'iteration': sti[1],
# How many approved search results were found for each product?
# +--------------------------------------------------+---------------------------+
# | product                                          |   approved_search_results |
# |--------------------------------------------------+---------------------------|
# | Lenovo ThinkPad T14s G2 Notebook computer        |                        21 |
# | Club Car IQ Electric Electric Golf Car           |                        20 |
# | E-Z-GO RXV Elite Golf Cart                       |                        20 |
# | CLUB CAR DS Golf cart                            |                        20 |
# | Chevrolet Traverse SUV                           |                        19 |
# | Park Cottage RV Recreational Vehicle             |                        19 |
# | Ford E-150 Cargo Van                             |                        19 |
# | Chrysler Voyager LX Minivan                      |                        18 |
# | Raymond 740R45TT Reach Forklift                  |                        18 |
# | Kubota LA525 Front Loader                        |                        18 |
# | Land Pride RCR1260 Rotary Cutter                 |                        18 |
# | B. Braun Infusomat Space Infusion Pump           |                        17 |
# | EZGO TXT PDS Golf Cart                           |                        17 |
# | Land Pride BB1260 Box Scraper                    |                        17 |
# | Yale GC050VX Forklift                            |                        16 |
# | E-Z-GO RXV-G Golf cart                           |                        16 |
# | Dell PowerEdge R740 Computer server              |                        15 |
# | Toyota 8FGCU25 Forklift                          |                        15 |
# | Xerox DocuMate 262 Document Scanner              |                        14 |
# | Intek Strength Pro Steel Dumbbell Pair Dumbbells |                        11 |
# +--------------------------------------------------+---------------------------+
#
#
# Search terms used in each iteration:
# Iteration 0:  ['ORIGINAL_NAME price list' 'ORIGINAL_NAME used prices'
#  'ORIGINAL_NAME blue book']
#
#
# Iteration 1:  ['ORIGINAL_NAME for sale' 'ORIGINAL_NAME pricing'
#  'buy ORIGINAL_NAME online' 'buy ORIGINAL_NAME'
#  'ORIGINAL_NAME pricing information'
#  'Club Car IQ Electric Golf Car pricing'
#  'buy Club Car IQ Electric Golf Car'
#  'Club Car IQ Electric Golf Car for sale online'
#  'ORIGINAL_NAME current market prices'
#  'ORIGINAL_NAME for sale with prices' 'ORIGINAL_NAME buy online'
#  'ORIGINAL_NAME price comparison' 'ORIGINAL_NAME prices'
#  'Park Cottage RV price comparison' 'buy Park Cottage RV online'
#  'ORIGINAL_NAME current prices' 'ORIGINAL_NAME listings for sale'
#  'ORIGINAL_NAME listings with prices']
#
#
# Iteration 2:  ['ORIGINAL_NAME price comparison' 'buy ORIGINAL_NAME used'
#  'ORIGINAL_NAME marketplace listings' 'ORIGINAL_NAME sales listings'
#  'ORIGINAL_NAME marketplace prices'
#  'Club Car IQ Electric Golf Car price comparison'
#  'buy Club Car IQ Electric Golf Car online'
#  'Club Car IQ Electric Golf Car listings with prices'
#  'ORIGINAL_NAME listings' 'ORIGINAL_NAME sale prices'
#  'ORIGINAL_NAME auction results' 'buy ORIGINAL_NAME price'
#  'ORIGINAL_NAME buy online' 'ORIGINAL_NAME for sale online'
#  'Park Cottage RV listings with prices' 'Park Cottage RV for sale near me'
#  'Park Cottage RV online marketplace' 'ORIGINAL_NAME sale listings'
#  'ORIGINAL_NAME current market prices' 'ORIGINAL_NAME for sale'
#  'buy ORIGINAL_NAME online' 'ORIGINAL_NAME for sale near me'
#  'buy used ORIGINAL_NAME online' 'ORIGINAL_NAME online prices'
#  'ORIGINAL_NAME market price' 'buy used ORIGINAL_NAME']
#
#
# Iteration 3:  ['ORIGINAL_NAME pricing guide' 'ORIGINAL_NAME sales prices'
#  'ORIGINAL_NAME auction results'
#  'buy Intek Strength Pro Steel Dumbbell Pair'
#  'Intek Strength Pro Steel Dumbbell Pair price online'
#  'Intek Strength Pro Steel Dumbbell Pair retail prices'
#  'ORIGINAL_NAME price online' 'ORIGINAL_NAME available for purchase'
#  'ORIGINAL_NAME price listings' 'ORIGINAL_NAME sale listings'
#  'ORIGINAL_NAME current prices']
#
#
# Iteration 4:  ['Intek Strength Pro Steel Dumbbell Pair prices for sale'
#  'Intek Strength Pro Steel Dumbbell Pair online store'
#  'Intek Strength Pro Steel Dumbbell Pair price listings'
#  'buy used Xerox DocuMate 262 Scanner'
#  'Xerox DocuMate 262 Scanner sale price' 'ORIGINAL_NAME price buy online']
#
#
# How many new URLs are found per product in each iteration on average?
# +-------------+----------------------+
# |   iteration |   average_urls_found |
# |-------------+----------------------|
# |           0 |                 12.6 |
# |           1 |                  6   |
# |           2 |                  4.1 |
# |           3 |                  0.6 |
# |           4 |                  0.2 |
# +-------------+----------------------+
#
#
# How many new URLs are approved per product in each iteration on average?
# +-------------+----------------------+
# |   iteration |   average_urls_found |
# |-------------+----------------------|
# |           0 |                  8.6 |
# |           1 |                  5.2 |
# |           2 |                  3.1 |
# |           3 |                  0.5 |
# |           4 |                  0.1 |
# +-------------+----------------------+
#
#
# What percentage of the URLs are approved per product in each iteration on average?
# +-------------+-----------------------+
# |   iteration |   percentage_approved |
# |-------------+-----------------------|
# |           0 |                  66.9 |
# |           1 |                  90.2 |
# |           2 |                  76.8 |
# |           3 |                  87.5 |
# |           4 |                  50   |
# +-------------+-----------------------+
#
#
# What percentage of the approved URLs for each product are found in each iteration on average?
# +-------------+----------------------------+
# |   iteration |   percentage_approved_urls |
# |-------------+----------------------------|
# |           0 |                       48.8 |
# |           1 |                       29.3 |
# |           2 |                       25.5 |
# |           3 |                       15.9 |
# |           4 |                        9.1 |
# +-------------+----------------------------+
#
#
# Which 20 search terms were the most effective in finding approved URLs?
# +----+-------------------------------------------+-------------------------------------------------------+---------------------------+------------+
# |    | product                                   | search_term                                           |   approved_search_results |   efficacy |
# |----+-------------------------------------------+-------------------------------------------------------+---------------------------+------------|
# |  0 | EZGO TXT PDS Golf Cart                    | EZGO TXT PDS Golf Cart used prices                    |                         5 |        100 |
# |  1 | Lenovo ThinkPad T14s G2 Notebook computer | Lenovo ThinkPad T14s G2 Notebook computer price list  |                         5 |        100 |
# |  2 | Land Pride BB1260 Box Scraper             | Land Pride BB1260 Box Scraper used prices             |                         5 |        100 |
# |  3 | Chevrolet Traverse SUV                    | Chevrolet Traverse SUV price list                     |                         5 |        100 |
# |  4 | Ford E-150 Cargo Van                      | Ford E-150 Cargo Van used prices                      |                         5 |        100 |
# |  5 | Chrysler Voyager LX Minivan               | Chrysler Voyager LX Minivan used prices               |                         5 |        100 |
# |  6 | CLUB CAR DS Golf cart                     | CLUB CAR DS Golf cart used prices                     |                         5 |        100 |
# |  7 | Dell PowerEdge R740 Computer server       | Dell PowerEdge R740 Computer server used prices       |                         5 |        100 |
# |  8 | Lenovo ThinkPad T14s G2 Notebook computer | Lenovo ThinkPad T14s G2 Notebook computer used prices |                         5 |        100 |
# |  9 | E-Z-GO RXV Elite Golf Cart                | E-Z-GO RXV Elite Golf Cart used prices                |                         5 |        100 |
# | 10 | E-Z-GO RXV-G Golf cart                    | E-Z-GO RXV-G Golf cart used prices                    |                         5 |        100 |
# | 11 | B. Braun Infusomat Space Infusion Pump    | B. Braun Infusomat Space Infusion Pump used prices    |                         5 |        100 |
# | 12 | Kubota LA525 Front Loader                 | Kubota LA525 Front Loader used prices                 |                         5 |        100 |
# | 13 | Land Pride RCR1260 Rotary Cutter          | Land Pride RCR1260 Rotary Cutter used prices          |                         5 |        100 |
# | 14 | Yale GC050VX Forklift                     | Yale GC050VX Forklift used prices                     |                         5 |        100 |
# | 15 | Chevrolet Traverse SUV                    | Chevrolet Traverse SUV used prices                    |                         5 |        100 |
# | 16 | Park Cottage RV Recreational Vehicle      | Park Cottage RV Recreational Vehicle for sale         |                         4 |         80 |
# | 17 | Chrysler Voyager LX Minivan               | Chrysler Voyager LX Minivan blue book                 |                         4 |         80 |
# | 18 | Lenovo ThinkPad T14s G2 Notebook computer | Lenovo ThinkPad T14s G2 Notebook computer buy online  |                         4 |        100 |
# | 19 | Dell PowerEdge R740 Computer server       | Dell PowerEdge R740 Computer server price list        |                         4 |        100 |
# +----+-------------------------------------------+-------------------------------------------------------+---------------------------+------------+
#
#
# Which 10 generic search terms were the most effective in finding approved URLs?
# +----+-----------------------+---------------------------+--------------------------------------------------+------------+
# |    | search_term_generic   |   approved_search_results |   proportion_of_total_results_across_commodities |   efficacy |
# |----+-----------------------+---------------------------+--------------------------------------------------+------------|
# |  0 | used prices           |                        89 |                                             25.6 |       96.7 |
# |  1 | price list            |                        55 |                                             15.8 |       88.7 |
# |  2 | for sale              |                        37 |                                             10.6 |       97.4 |
# |  3 | blue book             |                        27 |                                              7.8 |       27.3 |
# |  4 | buy online            |                        26 |                                              7.5 |       96.3 |
# |  5 | price comparison      |                        16 |                                              4.6 |       40   |
# |  6 | pricing               |                        13 |                                              3.7 |       92.9 |
# |  7 | buy                   |                        11 |                                              3.2 |       78.6 |
# |  8 | pricing information   |                         9 |                                              2.6 |       90   |
# |  9 | for sale near me      |                         8 |                                              2.3 |      100   |
# +----+-----------------------+---------------------------+--------------------------------------------------+------------+
#
#
# For how many iterations did the pipeline run for each product?
# +----+--------------------------------------------------+-------------+
# |    | product                                          |   iteration |
# |----+--------------------------------------------------+-------------|
# |  0 | Intek Strength Pro Steel Dumbbell Pair Dumbbells |           4 |
# |  1 | Xerox DocuMate 262 Document Scanner              |           4 |
# |  2 | Land Pride BB1260 Box Scraper                    |           3 |
# |  3 | Kubota LA525 Front Loader                        |           3 |
# |  4 | CLUB CAR DS Golf cart                            |           2 |
# |  5 | Toyota 8FGCU25 Forklift                          |           2 |
# |  6 | Raymond 740R45TT Reach Forklift                  |           2 |
# |  7 | Park Cottage RV Recreational Vehicle             |           2 |
# |  8 | Land Pride RCR1260 Rotary Cutter                 |           2 |
# |  9 | B. Braun Infusomat Space Infusion Pump           |           2 |
# | 10 | EZGO TXT PDS Golf Cart                           |           2 |
# | 11 | E-Z-GO RXV-G Golf cart                           |           2 |
# | 12 | Club Car IQ Electric Electric Golf Car           |           2 |
# | 13 | Yale GC050VX Forklift                            |           2 |
# | 14 | Ford E-150 Cargo Van                             |           1 |
# | 15 | E-Z-GO RXV Elite Golf Cart                       |           1 |
# | 16 | Lenovo ThinkPad T14s G2 Notebook computer        |           1 |
# | 17 | Dell PowerEdge R740 Computer server              |           1 |
# | 18 | Chrysler Voyager LX Minivan                      |           1 |
# | 19 | Chevrolet Traverse SUV                           |           1 |
# +----+--------------------------------------------------+-------------+
#
#
# Count values of number of iterations for each product:
# +----+-------------------+------------------------+
# |    |   n_of_iterations |   count_of_commodities |
# |----+-------------------+------------------------|
# |  0 |                 1 |                      6 |
# |  1 |                 2 |                     20 |
# |  2 |                 3 |                      6 |
# |  3 |                 4 |                      8 |
# +----+-------------------+------------------------+
#
#
# Full list of all search terms used per product:
# +-----+--------------------------------------------------+-------------------------------------------------------------------+
# |     | product                                          | search_term                                                       |
# |-----+--------------------------------------------------+-------------------------------------------------------------------|
# |   0 | E-Z-GO RXV Elite Golf Cart                       | E-Z-GO RXV Elite Golf Cart price list                             |
# |   1 | E-Z-GO RXV Elite Golf Cart                       | E-Z-GO RXV Elite Golf Cart used prices                            |
# |   2 | E-Z-GO RXV Elite Golf Cart                       | E-Z-GO RXV Elite Golf Cart blue book                              |
# |   3 | E-Z-GO RXV Elite Golf Cart                       | E-Z-GO RXV Elite Golf Cart for sale                               |
# |   4 | E-Z-GO RXV Elite Golf Cart                       | E-Z-GO RXV Elite Golf Cart pricing                                |
# |   5 | E-Z-GO RXV Elite Golf Cart                       | buy E-Z-GO RXV Elite Golf Cart online                             |
# |   6 | B. Braun Infusomat Space Infusion Pump           | B. Braun Infusomat Space Infusion Pump blue book                  |
# |   7 | B. Braun Infusomat Space Infusion Pump           | B. Braun Infusomat Space Infusion Pump price list                 |
# |   8 | B. Braun Infusomat Space Infusion Pump           | B. Braun Infusomat Space Infusion Pump used prices                |
# |   9 | B. Braun Infusomat Space Infusion Pump           | B. Braun Infusomat Space Infusion Pump for sale                   |
# |  10 | B. Braun Infusomat Space Infusion Pump           | B. Braun Infusomat Space Infusion Pump pricing                    |
# |  11 | B. Braun Infusomat Space Infusion Pump           | buy B. Braun Infusomat Space Infusion Pump online                 |
# |  12 | B. Braun Infusomat Space Infusion Pump           | B. Braun Infusomat Space Infusion Pump price comparison           |
# |  13 | B. Braun Infusomat Space Infusion Pump           | buy B. Braun Infusomat Space Infusion Pump used                   |
# |  14 | B. Braun Infusomat Space Infusion Pump           | B. Braun Infusomat Space Infusion Pump marketplace listings       |
# |  15 | CLUB CAR DS Golf cart                            | CLUB CAR DS Golf cart used prices                                 |
# |  16 | CLUB CAR DS Golf cart                            | CLUB CAR DS Golf cart price list                                  |
# |  17 | CLUB CAR DS Golf cart                            | CLUB CAR DS Golf cart blue book                                   |
# |  18 | CLUB CAR DS Golf cart                            | CLUB CAR DS Golf cart for sale                                    |
# |  19 | CLUB CAR DS Golf cart                            | buy CLUB CAR DS Golf cart                                         |
# |  20 | CLUB CAR DS Golf cart                            | CLUB CAR DS Golf cart pricing information                         |
# |  21 | CLUB CAR DS Golf cart                            | CLUB CAR DS Golf cart sales listings                              |
# |  22 | CLUB CAR DS Golf cart                            | CLUB CAR DS Golf cart price comparison                            |
# |  23 | CLUB CAR DS Golf cart                            | CLUB CAR DS Golf cart marketplace prices                          |
# |  24 | Club Car IQ Electric Electric Golf Car           | Club Car IQ Electric Electric Golf Car blue book                  |
# |  25 | Club Car IQ Electric Electric Golf Car           | Club Car IQ Electric Electric Golf Car price list                 |
# |  26 | Club Car IQ Electric Electric Golf Car           | Club Car IQ Electric Electric Golf Car used prices                |
# |  27 | Club Car IQ Electric Electric Golf Car           | Club Car IQ Electric Golf Car pricing                             |
# |  28 | Club Car IQ Electric Electric Golf Car           | buy Club Car IQ Electric Golf Car                                 |
# |  29 | Club Car IQ Electric Electric Golf Car           | Club Car IQ Electric Golf Car for sale online                     |
# |  30 | Club Car IQ Electric Electric Golf Car           | Club Car IQ Electric Golf Car price comparison                    |
# |  31 | Club Car IQ Electric Electric Golf Car           | buy Club Car IQ Electric Golf Car online                          |
# |  32 | Club Car IQ Electric Electric Golf Car           | Club Car IQ Electric Golf Car listings with prices                |
# |  33 | Yale GC050VX Forklift                            | Yale GC050VX Forklift blue book                                   |
# |  34 | Yale GC050VX Forklift                            | Yale GC050VX Forklift used prices                                 |
# |  35 | Yale GC050VX Forklift                            | Yale GC050VX Forklift price list                                  |
# |  36 | Yale GC050VX Forklift                            | Yale GC050VX Forklift for sale                                    |
# |  37 | Yale GC050VX Forklift                            | Yale GC050VX Forklift pricing                                     |
# |  38 | Yale GC050VX Forklift                            | buy Yale GC050VX Forklift online                                  |
# |  39 | Yale GC050VX Forklift                            | Yale GC050VX Forklift listings                                    |
# |  40 | Yale GC050VX Forklift                            | Yale GC050VX Forklift sale prices                                 |
# |  41 | Yale GC050VX Forklift                            | Yale GC050VX Forklift auction results                             |
# |  42 | Chevrolet Traverse SUV                           | Chevrolet Traverse SUV used prices                                |
# |  43 | Chevrolet Traverse SUV                           | Chevrolet Traverse SUV price list                                 |
# |  44 | Chevrolet Traverse SUV                           | Chevrolet Traverse SUV blue book                                  |
# |  45 | Chevrolet Traverse SUV                           | Chevrolet Traverse SUV current market prices                      |
# |  46 | Chevrolet Traverse SUV                           | Chevrolet Traverse SUV pricing information                        |
# |  47 | Chevrolet Traverse SUV                           | Chevrolet Traverse SUV for sale with prices                       |
# |  48 | Lenovo ThinkPad T14s G2 Notebook computer        | Lenovo ThinkPad T14s G2 Notebook computer price list              |
# |  49 | Lenovo ThinkPad T14s G2 Notebook computer        | Lenovo ThinkPad T14s G2 Notebook computer blue book               |
# |  50 | Lenovo ThinkPad T14s G2 Notebook computer        | Lenovo ThinkPad T14s G2 Notebook computer used prices             |
# |  51 | Lenovo ThinkPad T14s G2 Notebook computer        | Lenovo ThinkPad T14s G2 Notebook computer buy online              |
# |  52 | Lenovo ThinkPad T14s G2 Notebook computer        | Lenovo ThinkPad T14s G2 Notebook computer price comparison        |
# |  53 | Lenovo ThinkPad T14s G2 Notebook computer        | Lenovo ThinkPad T14s G2 Notebook computer for sale                |
# |  54 | Ford E-150 Cargo Van                             | Ford E-150 Cargo Van used prices                                  |
# |  55 | Ford E-150 Cargo Van                             | Ford E-150 Cargo Van price list                                   |
# |  56 | Ford E-150 Cargo Van                             | Ford E-150 Cargo Van blue book                                    |
# |  57 | Ford E-150 Cargo Van                             | Ford E-150 Cargo Van for sale                                     |
# |  58 | Ford E-150 Cargo Van                             | Ford E-150 Cargo Van pricing                                      |
# |  59 | Ford E-150 Cargo Van                             | buy Ford E-150 Cargo Van online                                   |
# |  60 | Kubota LA525 Front Loader                        | Kubota LA525 Front Loader blue book                               |
# |  61 | Kubota LA525 Front Loader                        | Kubota LA525 Front Loader price list                              |
# |  62 | Kubota LA525 Front Loader                        | Kubota LA525 Front Loader used prices                             |
# |  63 | Kubota LA525 Front Loader                        | Kubota LA525 Front Loader for sale                                |
# |  64 | Kubota LA525 Front Loader                        | Kubota LA525 Front Loader pricing                                 |
# |  65 | Kubota LA525 Front Loader                        | buy Kubota LA525 Front Loader online                              |
# |  66 | Kubota LA525 Front Loader                        | buy Kubota LA525 Front Loader price                               |
# |  67 | Kubota LA525 Front Loader                        | Kubota LA525 Front Loader sales listings                          |
# |  68 | Kubota LA525 Front Loader                        | Kubota LA525 Front Loader marketplace prices                      |
# |  69 | Kubota LA525 Front Loader                        | Kubota LA525 Front Loader pricing guide                           |
# |  70 | Kubota LA525 Front Loader                        | Kubota LA525 Front Loader sales prices                            |
# |  71 | Kubota LA525 Front Loader                        | Kubota LA525 Front Loader auction results                         |
# |  72 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair Dumbbells blue book        |
# |  73 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair Dumbbells price list       |
# |  74 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair Dumbbells used prices      |
# |  75 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair Dumbbells prices           |
# |  76 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | buy Intek Strength Pro Steel Dumbbell Pair Dumbbells              |
# |  77 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair Dumbbells for sale         |
# |  78 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair Dumbbells buy online       |
# |  79 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair Dumbbells price comparison |
# |  80 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair Dumbbells for sale online  |
# |  81 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | buy Intek Strength Pro Steel Dumbbell Pair                        |
# |  82 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair price online               |
# |  83 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair retail prices              |
# |  84 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair prices for sale            |
# |  85 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair online store               |
# |  86 | Intek Strength Pro Steel Dumbbell Pair Dumbbells | Intek Strength Pro Steel Dumbbell Pair price listings             |
# |  87 | Dell PowerEdge R740 Computer server              | Dell PowerEdge R740 Computer server blue book                     |
# |  88 | Dell PowerEdge R740 Computer server              | Dell PowerEdge R740 Computer server price list                    |
# |  89 | Dell PowerEdge R740 Computer server              | Dell PowerEdge R740 Computer server used prices                   |
# |  90 | Dell PowerEdge R740 Computer server              | Dell PowerEdge R740 Computer server price comparison              |
# |  91 | Dell PowerEdge R740 Computer server              | Dell PowerEdge R740 Computer server for sale                      |
# |  92 | Dell PowerEdge R740 Computer server              | Dell PowerEdge R740 Computer server pricing information           |
# |  93 | Park Cottage RV Recreational Vehicle             | Park Cottage RV Recreational Vehicle used prices                  |
# |  94 | Park Cottage RV Recreational Vehicle             | Park Cottage RV Recreational Vehicle price list                   |
# |  95 | Park Cottage RV Recreational Vehicle             | Park Cottage RV Recreational Vehicle blue book                    |
# |  96 | Park Cottage RV Recreational Vehicle             | Park Cottage RV Recreational Vehicle for sale                     |
# |  97 | Park Cottage RV Recreational Vehicle             | Park Cottage RV price comparison                                  |
# |  98 | Park Cottage RV Recreational Vehicle             | buy Park Cottage RV online                                        |
# |  99 | Park Cottage RV Recreational Vehicle             | Park Cottage RV listings with prices                              |
# | 100 | Park Cottage RV Recreational Vehicle             | Park Cottage RV for sale near me                                  |
# | 101 | Park Cottage RV Recreational Vehicle             | Park Cottage RV online marketplace                                |
# | 102 | E-Z-GO RXV-G Golf cart                           | E-Z-GO RXV-G Golf cart blue book                                  |
# | 103 | E-Z-GO RXV-G Golf cart                           | E-Z-GO RXV-G Golf cart used prices                                |
# | 104 | E-Z-GO RXV-G Golf cart                           | E-Z-GO RXV-G Golf cart price list                                 |
# | 105 | E-Z-GO RXV-G Golf cart                           | E-Z-GO RXV-G Golf cart for sale                                   |
# | 106 | E-Z-GO RXV-G Golf cart                           | E-Z-GO RXV-G Golf cart pricing                                    |
# | 107 | E-Z-GO RXV-G Golf cart                           | buy E-Z-GO RXV-G Golf cart online                                 |
# | 108 | E-Z-GO RXV-G Golf cart                           | E-Z-GO RXV-G Golf cart price comparison                           |
# | 109 | E-Z-GO RXV-G Golf cart                           | E-Z-GO RXV-G Golf cart sale listings                              |
# | 110 | E-Z-GO RXV-G Golf cart                           | E-Z-GO RXV-G Golf cart current market prices                      |
# | 111 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner used prices                   |
# | 112 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner price list                    |
# | 113 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner blue book                     |
# | 114 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner buy online                    |
# | 115 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner current prices                |
# | 116 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner listings for sale             |
# | 117 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner for sale                      |
# | 118 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner price comparison              |
# | 119 | Xerox DocuMate 262 Document Scanner              | buy Xerox DocuMate 262 Document Scanner online                    |
# | 120 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner price online                  |
# | 121 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner available for purchase        |
# | 122 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner price listings                |
# | 123 | Xerox DocuMate 262 Document Scanner              | buy used Xerox DocuMate 262 Scanner                               |
# | 124 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Scanner sale price                             |
# | 125 | Xerox DocuMate 262 Document Scanner              | Xerox DocuMate 262 Document Scanner price buy online              |
# | 126 | Chrysler Voyager LX Minivan                      | Chrysler Voyager LX Minivan used prices                           |
# | 127 | Chrysler Voyager LX Minivan                      | Chrysler Voyager LX Minivan blue book                             |
# | 128 | Chrysler Voyager LX Minivan                      | Chrysler Voyager LX Minivan price list                            |
# | 129 | Chrysler Voyager LX Minivan                      | Chrysler Voyager LX Minivan for sale                              |
# | 130 | Chrysler Voyager LX Minivan                      | Chrysler Voyager LX Minivan price comparison                      |
# | 131 | Chrysler Voyager LX Minivan                      | Chrysler Voyager LX Minivan listings with prices                  |
# | 132 | Toyota 8FGCU25 Forklift                          | Toyota 8FGCU25 Forklift price list                                |
# | 133 | Toyota 8FGCU25 Forklift                          | Toyota 8FGCU25 Forklift used prices                               |
# | 134 | Toyota 8FGCU25 Forklift                          | Toyota 8FGCU25 Forklift blue book                                 |
# | 135 | Toyota 8FGCU25 Forklift                          | Toyota 8FGCU25 Forklift for sale                                  |
# | 136 | Toyota 8FGCU25 Forklift                          | Toyota 8FGCU25 Forklift pricing                                   |
# | 137 | Toyota 8FGCU25 Forklift                          | buy Toyota 8FGCU25 Forklift online                                |
# | 138 | Toyota 8FGCU25 Forklift                          | Toyota 8FGCU25 Forklift price comparison                          |
# | 139 | Toyota 8FGCU25 Forklift                          | Toyota 8FGCU25 Forklift for sale near me                          |
# | 140 | Toyota 8FGCU25 Forklift                          | buy used Toyota 8FGCU25 Forklift online                           |
# | 141 | Land Pride BB1260 Box Scraper                    | Land Pride BB1260 Box Scraper price list                          |
# | 142 | Land Pride BB1260 Box Scraper                    | Land Pride BB1260 Box Scraper used prices                         |
# | 143 | Land Pride BB1260 Box Scraper                    | Land Pride BB1260 Box Scraper blue book                           |
# | 144 | Land Pride BB1260 Box Scraper                    | Land Pride BB1260 Box Scraper for sale                            |
# | 145 | Land Pride BB1260 Box Scraper                    | buy Land Pride BB1260 Box Scraper                                 |
# | 146 | Land Pride BB1260 Box Scraper                    | Land Pride BB1260 Box Scraper price comparison                    |
# | 147 | Land Pride BB1260 Box Scraper                    | Land Pride BB1260 Box Scraper online prices                       |
# | 148 | Land Pride BB1260 Box Scraper                    | buy Land Pride BB1260 Box Scraper used                            |
# | 149 | Land Pride BB1260 Box Scraper                    | Land Pride BB1260 Box Scraper marketplace listings                |
# | 150 | Land Pride BB1260 Box Scraper                    | Land Pride BB1260 Box Scraper price online                        |
# | 151 | Land Pride BB1260 Box Scraper                    | Land Pride BB1260 Box Scraper sale listings                       |
# | 152 | Land Pride BB1260 Box Scraper                    | Land Pride BB1260 Box Scraper current prices                      |
# | 153 | Raymond 740R45TT Reach Forklift                  | Raymond 740R45TT Reach Forklift used prices                       |
# | 154 | Raymond 740R45TT Reach Forklift                  | Raymond 740R45TT Reach Forklift blue book                         |
# | 155 | Raymond 740R45TT Reach Forklift                  | Raymond 740R45TT Reach Forklift price list                        |
# | 156 | Raymond 740R45TT Reach Forklift                  | Raymond 740R45TT Reach Forklift for sale                          |
# | 157 | Raymond 740R45TT Reach Forklift                  | Raymond 740R45TT Reach Forklift pricing                           |
# | 158 | Raymond 740R45TT Reach Forklift                  | buy Raymond 740R45TT Reach Forklift online                        |
# | 159 | Raymond 740R45TT Reach Forklift                  | Raymond 740R45TT Reach Forklift listings                          |
# | 160 | Raymond 740R45TT Reach Forklift                  | Raymond 740R45TT Reach Forklift for sale near me                  |
# | 161 | Raymond 740R45TT Reach Forklift                  | Raymond 740R45TT Reach Forklift market price                      |
# | 162 | EZGO TXT PDS Golf Cart                           | EZGO TXT PDS Golf Cart price list                                 |
# | 163 | EZGO TXT PDS Golf Cart                           | EZGO TXT PDS Golf Cart used prices                                |
# | 164 | EZGO TXT PDS Golf Cart                           | EZGO TXT PDS Golf Cart blue book                                  |
# | 165 | EZGO TXT PDS Golf Cart                           | buy EZGO TXT PDS Golf Cart                                        |
# | 166 | EZGO TXT PDS Golf Cart                           | EZGO TXT PDS Golf Cart for sale                                   |
# | 167 | EZGO TXT PDS Golf Cart                           | EZGO TXT PDS Golf Cart pricing information                        |
# | 168 | EZGO TXT PDS Golf Cart                           | EZGO TXT PDS Golf Cart listings                                   |
# | 169 | EZGO TXT PDS Golf Cart                           | buy used EZGO TXT PDS Golf Cart                                   |
# | 170 | EZGO TXT PDS Golf Cart                           | EZGO TXT PDS Golf Cart price comparison                           |
# | 171 | Land Pride RCR1260 Rotary Cutter                 | Land Pride RCR1260 Rotary Cutter used prices                      |
# | 172 | Land Pride RCR1260 Rotary Cutter                 | Land Pride RCR1260 Rotary Cutter price list                       |
# | 173 | Land Pride RCR1260 Rotary Cutter                 | Land Pride RCR1260 Rotary Cutter blue book                        |
# | 174 | Land Pride RCR1260 Rotary Cutter                 | buy Land Pride RCR1260 Rotary Cutter                              |
# | 175 | Land Pride RCR1260 Rotary Cutter                 | Land Pride RCR1260 Rotary Cutter for sale                         |
# | 176 | Land Pride RCR1260 Rotary Cutter                 | Land Pride RCR1260 Rotary Cutter pricing information              |
# | 177 | Land Pride RCR1260 Rotary Cutter                 | Land Pride RCR1260 Rotary Cutter price comparison                 |
# | 178 | Land Pride RCR1260 Rotary Cutter                 | Land Pride RCR1260 Rotary Cutter listings                         |
# | 179 | Land Pride RCR1260 Rotary Cutter                 | Land Pride RCR1260 Rotary Cutter for sale near me                 |
# +-----+--------------------------------------------------+-------------------------------------------------------------------+

# %%
analytics_report(raw_responses_commodities, item_type='commodity')
# Out:
# /home/sosajuanbautista/aeai-filestore/projects/agentic/codes/price_retrieval/llm_agentic_app_for_price_sources.py:819: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   output_df = pd.concat([output_df, pd.DataFrame({item_type: item, 'iteration': sti[1],
# How many approved search results were found for each commodity?
# +------------------------------------------------------+---------------------------+
# | commodity                                            |   approved_search_results |
# |------------------------------------------------------+---------------------------|
# | Notebook computer                                    |                        20 |
# | Rotary tiller or power tiller                        |                        19 |
# | Automobiles or cars                                  |                        17 |
# | Inkjet printer for commercial printing applications  |                        17 |
# | Multifunction machines                               |                        17 |
# | Computer server                                      |                        17 |
# | Forklifts                                            |                        16 |
# | General tool kits                                    |                        16 |
# | Office product equipment and stationery consumable   |                        16 |
# | Photocopiers                                         |                        16 |
# | Mowers                                               |                        15 |
# | Desktop computer                                     |                        15 |
# | Toothbrush or tumbler holder                         |                        15 |
# | Track excavators                                     |                        15 |
# | Trim or molding tools                                |                        15 |
# | Farming excavator                                    |                        13 |
# | Gabion block                                         |                        12 |
# | Battery energy storage control and management system |                        12 |
# | Personal computer                                    |                         9 |
# | Solar power plants                                   |                         4 |
# +------------------------------------------------------+---------------------------+
#
#
# Search terms used in each iteration:
# Iteration 0:  ['ORIGINAL_NAME price list' 'ORIGINAL_NAME blue book'
#  'ORIGINAL_NAME used prices']
#
#
# Iteration 1:  ['Rotary tiller price comparison' 'Power tiller for sale with prices'
#  'Buy rotary tiller online prices' 'farming excavator for sale'
#  'buy farming excavator online' 'farming excavator pricing guide'
#  'buy mowers online' 'mower price comparison'
#  'mowers for sale with prices' 'ORIGINAL_NAME for sale'
#  'Track excavator price list' 'Buy track excavators online'
#  'ORIGINAL_NAME for sale with prices' 'Used forklifts price comparison'
#  'Forklift pricing guide' 'buy used cars online'
#  'automobile pricing guide' 'car listings with prices'
#  'Battery energy storage management system price comparison'
#  'Battery energy storage systems for sale'
#  'Battery energy storage control system pricing'
#  'solar power plant pricing guide' 'solar energy system cost comparison'
#  'commercial solar power plant prices' 'buy general tool kits online'
#  'general tool kits price comparison' 'general tool kits for sale'
#  'Trim molding tools pricing' 'Buy trim molding tools online'
#  'Trim molding tools for sale with prices' 'ORIGINAL_NAME pricing'
#  'ORIGINAL_NAME suppliers' 'ORIGINAL_NAME cost comparison'
#  'Toothbrush holder prices' 'Tumbler holder price list'
#  'Buy toothbrush and tumbler holders online' 'buy computer server online'
#  'computer server pricing guide' 'computer server marketplace'
#  'ORIGINAL_NAME price comparison' 'Buy notebook computers online'
#  'Notebook laptop pricing guide' 'buy desktop computer prices'
#  'desktop computer price comparison' 'desktop computer listings for sale'
#  'buy personal computer online' 'personal computer price comparison'
#  'current personal computer listings' 'buy photocopiers online'
#  'photocopier prices comparison' 'photocopier sales listings'
#  'buy multifunction machines online'
#  'multifunction machines price comparison'
#  'multifunction printer prices list' 'Office supplies price comparison'
#  'Office equipment and stationery price listings'
#  'Buy office products online with prices'
#  'commercial inkjet printer price comparison'
#  'buy inkjet printers for commercial use'
#  'inkjet printer pricing online marketplace']
#
#
# Iteration 2:  ['Rotary tiller prices online' 'Power tiller product listings'
#  'Buy rotary tiller prices comparison' 'farming excavator marketplace'
#  'buy used farming excavator' 'farming excavator sales listings'
#  'lawn mower prices' 'mowers for sale online'
#  'buy lawn mowers with prices' 'Track excavator pricing information'
#  'Track excavator sales listings' 'Used track excavators price guide'
#  'current car prices' 'automobile price comparison'
#  'used car listings with prices' 'Battery storage systems price directory'
#  'Battery energy storage system product catalog'
#  'Buy battery energy storage management systems online'
#  'solar power plant product listings' 'solar power plant pricing online'
#  'solar power plant models with prices' 'general tool kits price listings'
#  'buy tool kits online prices' 'tool kits e-commerce sites'
#  'Trim molding tools price comparison' 'Trim molding tools online store'
#  'Buy trim molding tools with prices' 'ORIGINAL_NAME online store'
#  'ORIGINAL_NAME price quotes' 'ORIGINAL_NAME product catalog'
#  'computer server price comparison' 'buy computer server prices'
#  'computer server product listings' 'ORIGINAL_NAME pricing online'
#  'Buy notebook laptops with prices' 'ORIGINAL_NAME price listings'
#  'desktop computer sales' 'desktop computer price listings'
#  'buy desktop computers online' 'personal computer price database'
#  'personal computer sales listings' 'buy personal computer prices online'
#  'buy multifunction machines' 'multifunction printer price listings'
#  'multifunction machines for sale online' 'Office supplies prices online'
#  'Stationery products price catalog' 'Office equipment price listings'
#  'commercial inkjet printer price listings'
#  'buy commercial inkjet printers online'
#  'inkjet printer prices for business use']
#
#
# Iteration 3:  ['farming excavator price comparison' 'farming excavator online listings'
#  'farming excavator sales database'
#  'Battery energy storage systems price quotes'
#  'Battery storage management systems pricing information'
#  'Battery energy storage system listings with prices'
#  'solar power plant equipment prices'
#  'solar power plant suppliers pricing' 'solar power plant cost listings'
#  'ORIGINAL_NAME product prices' 'ORIGINAL_NAME suppliers price list'
#  'ORIGINAL_NAME e-commerce prices' 'computer server price directory'
#  'computer server inventory with prices' 'computer server sales listings'
#  'Notebook laptop prices' 'ORIGINAL_NAME sales'
#  'Buy used notebook laptops' 'personal computer pricing guide'
#  'buy personal computers online' 'personal computer model price list'
#  'commercial inkjet printer price directory'
#  'inkjet printers for business pricing'
#  'buy commercial inkjet printers online prices']
#
#
# Iteration 4:  ['farming excavator online catalog' 'farming excavator sales prices'
#  'new and used farming excavators for sale'
#  'Battery energy storage systems price comparison tool'
#  'Buy battery management systems with prices'
#  'Battery storage systems for sale online with prices'
#  'solar power plant price quotes'
#  'solar power plant equipment price comparison'
#  'solar power plant model pricing directory'
#  'ORIGINAL_NAME price comparison site' 'ORIGINAL_NAME online marketplace'
#  'Buy ORIGINAL_NAME prices' 'computer server price listings'
#  'current computer server prices' 'computer server online catalog'
#  'current personal computer prices' 'online personal computer prices'
#  'personal computer price listings'
#  'commercial inkjet printer online prices'
#  'inkjet printer sales for businesses'
#  'purchase commercial inkjet printer models with prices']
#
#
# How many new URLs are found per commodity in each iteration on average?
# +-------------+----------------------+
# |   iteration |   average_urls_found |
# |-------------+----------------------|
# |           0 |                  6.1 |
# |           1 |                  9.4 |
# |           2 |                  5.2 |
# |           3 |                  1.5 |
# |           4 |                  1.3 |
# +-------------+----------------------+
#
#
# How many new URLs are approved per commodity in each iteration on average?
# +-------------+----------------------+
# |   iteration |   average_urls_found |
# |-------------+----------------------|
# |           0 |                  2.5 |
# |           1 |                  6.7 |
# |           2 |                  3.6 |
# |           3 |                  1   |
# |           4 |                  0.9 |
# +-------------+----------------------+
#
#
# What percentage of the URLs are approved per commodity in each iteration on average?
# +-------------+-----------------------+
# |   iteration |   percentage_approved |
# |-------------+-----------------------|
# |           0 |                  47.9 |
# |           1 |                  73.8 |
# |           2 |                  73.7 |
# |           3 |                  76.7 |
# |           4 |                  75   |
# +-------------+-----------------------+
#
#
# What percentage of the approved URLs for each commodity are found in each iteration on average?
# +-------------+----------------------------+
# |   iteration |   percentage_approved_urls |
# |-------------+----------------------------|
# |           0 |                       16.6 |
# |           1 |                       45.5 |
# |           2 |                       28.7 |
# |           3 |                       17   |
# |           4 |                       19.4 |
# +-------------+----------------------------+
#
#
# Which 20 search terms were the most effective in finding approved URLs?
# +----+-----------------------------------------------------+-------------------------------------------+---------------------------+------------+
# |    | commodity                                           | search_term                               |   approved_search_results |   efficacy |
# |----+-----------------------------------------------------+-------------------------------------------+---------------------------+------------|
# |  0 | Toothbrush or tumbler holder                        | Toothbrush holder prices                  |                         5 |        100 |
# |  1 | Trim or molding tools                               | Trim molding tools pricing                |                         5 |        100 |
# |  2 | Desktop computer                                    | buy desktop computer prices               |                         5 |        100 |
# |  3 | Notebook computer                                   | Buy used notebook laptops                 |                         5 |        100 |
# |  4 | Automobiles or cars                                 | used car listings with prices             |                         5 |        100 |
# |  5 | Photocopiers                                        | Photocopiers used prices                  |                         5 |        100 |
# |  6 | Forklifts                                           | Forklifts for sale with prices            |                         5 |        100 |
# |  7 | Rotary tiller or power tiller                       | Power tiller for sale with prices         |                         5 |        100 |
# |  8 | Inkjet printer for commercial printing applications | inkjet printers for business pricing      |                         4 |        100 |
# |  9 | Office product equipment and stationery consumable  | Office supplies prices online             |                         4 |        100 |
# | 10 | Multifunction machines                              | multifunction printer prices list         |                         4 |        100 |
# | 11 | Multifunction machines                              | buy multifunction machines online         |                         4 |        100 |
# | 12 | Photocopiers                                        | buy photocopiers online                   |                         4 |        100 |
# | 13 | Rotary tiller or power tiller                       | Buy rotary tiller online prices           |                         4 |        100 |
# | 14 | Mowers                                              | Mowers used prices                        |                         4 |        100 |
# | 15 | Toothbrush or tumbler holder                        | Buy toothbrush and tumbler holders online |                         4 |        100 |
# | 16 | Notebook computer                                   | Notebook computer price comparison        |                         4 |         80 |
# | 17 | General tool kits                                   | buy general tool kits online              |                         4 |        100 |
# | 18 | Toothbrush or tumbler holder                        | Tumbler holder price list                 |                         4 |         80 |
# | 19 | General tool kits                                   | general tool kits price listings          |                         4 |        100 |
# +----+-----------------------------------------------------+-------------------------------------------+---------------------------+------------+
#
#
# Which 10 generic search terms were the most effective in finding approved URLs?
# +----+-----------------------+---------------------------+--------------------------------------------------+------------+
# |    | search_term_generic   |   approved_search_results |   proportion_of_total_results_across_commodities |   efficacy |
# |----+-----------------------+---------------------------+--------------------------------------------------+------------|
# |  0 | used prices           |                        28 |                                              9.5 |       68.3 |
# |  1 | buy online            |                        28 |                                              9.5 |       93.3 |
# |  2 | price list            |                        19 |                                              6.4 |       57.6 |
# |  3 | price listings        |                        16 |                                              5.4 |       84.2 |
# |  4 | sales listings        |                        15 |                                              5.1 |       93.8 |
# |  5 | for sale with prices  |                        14 |                                              4.7 |      100   |
# |  6 | price comparison      |                        11 |                                              3.7 |       34.4 |
# |  7 | for sale              |                         9 |                                              3   |       64.3 |
# |  8 | pricing               |                         8 |                                              2.7 |       80   |
# |  9 | blue book             |                         8 |                                              2.7 |       14.5 |
# +----+-----------------------+---------------------------+--------------------------------------------------+------------+
#
#
# For how many iterations did the pipeline run for each commodity?
# +----+------------------------------------------------------+-------------+
# |    | commodity                                            |   iteration |
# |----+------------------------------------------------------+-------------|
# |  0 | Computer server                                      |           4 |
# |  1 | Farming excavator                                    |           4 |
# |  2 | Solar power plants                                   |           4 |
# |  3 | Gabion block                                         |           4 |
# |  4 | Inkjet printer for commercial printing applications  |           4 |
# |  5 | Personal computer                                    |           4 |
# |  6 | Battery energy storage control and management system |           4 |
# |  7 | Notebook computer                                    |           3 |
# |  8 | Automobiles or cars                                  |           2 |
# |  9 | Office product equipment and stationery consumable   |           2 |
# | 10 | Track excavators                                     |           2 |
# | 11 | Rotary tiller or power tiller                        |           2 |
# | 12 | Multifunction machines                               |           2 |
# | 13 | Mowers                                               |           2 |
# | 14 | General tool kits                                    |           2 |
# | 15 | Desktop computer                                     |           2 |
# | 16 | Trim or molding tools                                |           2 |
# | 17 | Photocopiers                                         |           1 |
# | 18 | Forklifts                                            |           1 |
# | 19 | Toothbrush or tumbler holder                         |           1 |
# +----+------------------------------------------------------+-------------+
#
#
# Count values of number of iterations for each commodity:
# +----+-------------------+------------------------+
# |    |   n_of_iterations |   count_of_commodities |
# |----+-------------------+------------------------|
# |  0 |                 1 |                      3 |
# |  1 |                 2 |                     18 |
# |  2 |                 3 |                      3 |
# |  3 |                 4 |                     28 |
# +----+-------------------+------------------------+
#
#
# Full list of all search terms used per commodity:
# +-----+------------------------------------------------------+------------------------------------------------------------------+
# |     | commodity                                            | search_term                                                      |
# |-----+------------------------------------------------------+------------------------------------------------------------------|
# |   0 | Rotary tiller or power tiller                        | Rotary tiller or power tiller price list                         |
# |   1 | Rotary tiller or power tiller                        | Rotary tiller or power tiller blue book                          |
# |   2 | Rotary tiller or power tiller                        | Rotary tiller or power tiller used prices                        |
# |   3 | Rotary tiller or power tiller                        | Rotary tiller price comparison                                   |
# |   4 | Rotary tiller or power tiller                        | Power tiller for sale with prices                                |
# |   5 | Rotary tiller or power tiller                        | Buy rotary tiller online prices                                  |
# |   6 | Rotary tiller or power tiller                        | Rotary tiller prices online                                      |
# |   7 | Rotary tiller or power tiller                        | Power tiller product listings                                    |
# |   8 | Rotary tiller or power tiller                        | Buy rotary tiller prices comparison                              |
# |   9 | Farming excavator                                    | Farming excavator price list                                     |
# |  10 | Farming excavator                                    | Farming excavator blue book                                      |
# |  11 | Farming excavator                                    | Farming excavator used prices                                    |
# |  12 | Farming excavator                                    | farming excavator for sale                                       |
# |  13 | Farming excavator                                    | buy farming excavator online                                     |
# |  14 | Farming excavator                                    | farming excavator pricing guide                                  |
# |  15 | Farming excavator                                    | farming excavator marketplace                                    |
# |  16 | Farming excavator                                    | buy used farming excavator                                       |
# |  17 | Farming excavator                                    | farming excavator sales listings                                 |
# |  18 | Farming excavator                                    | farming excavator price comparison                               |
# |  19 | Farming excavator                                    | farming excavator online listings                                |
# |  20 | Farming excavator                                    | farming excavator sales database                                 |
# |  21 | Farming excavator                                    | farming excavator online catalog                                 |
# |  22 | Farming excavator                                    | farming excavator sales prices                                   |
# |  23 | Farming excavator                                    | new and used farming excavators for sale                         |
# |  24 | Mowers                                               | Mowers blue book                                                 |
# |  25 | Mowers                                               | Mowers price list                                                |
# |  26 | Mowers                                               | Mowers used prices                                               |
# |  27 | Mowers                                               | buy mowers online                                                |
# |  28 | Mowers                                               | mower price comparison                                           |
# |  29 | Mowers                                               | mowers for sale with prices                                      |
# |  30 | Mowers                                               | lawn mower prices                                                |
# |  31 | Mowers                                               | mowers for sale online                                           |
# |  32 | Mowers                                               | buy lawn mowers with prices                                      |
# |  33 | Track excavators                                     | Track excavators blue book                                       |
# |  34 | Track excavators                                     | Track excavators used prices                                     |
# |  35 | Track excavators                                     | Track excavators for sale                                        |
# |  36 | Track excavators                                     | Track excavator price list                                       |
# |  37 | Track excavators                                     | Buy track excavators online                                      |
# |  38 | Track excavators                                     | Track excavator pricing information                              |
# |  39 | Track excavators                                     | Track excavator sales listings                                   |
# |  40 | Track excavators                                     | Used track excavators price guide                                |
# |  41 | Forklifts                                            | Forklifts used prices                                            |
# |  42 | Forklifts                                            | Forklifts blue book                                              |
# |  43 | Forklifts                                            | Forklifts price list                                             |
# |  44 | Forklifts                                            | Forklifts for sale with prices                                   |
# |  45 | Forklifts                                            | Used forklifts price comparison                                  |
# |  46 | Forklifts                                            | Forklift pricing guide                                           |
# |  47 | Automobiles or cars                                  | Automobiles or cars price list                                   |
# |  48 | Automobiles or cars                                  | Automobiles or cars blue book                                    |
# |  49 | Automobiles or cars                                  | Automobiles or cars used prices                                  |
# |  50 | Automobiles or cars                                  | buy used cars online                                             |
# |  51 | Automobiles or cars                                  | automobile pricing guide                                         |
# |  52 | Automobiles or cars                                  | car listings with prices                                         |
# |  53 | Automobiles or cars                                  | current car prices                                               |
# |  54 | Automobiles or cars                                  | automobile price comparison                                      |
# |  55 | Automobiles or cars                                  | used car listings with prices                                    |
# |  56 | Battery energy storage control and management system | Battery energy storage control and management system price list  |
# |  57 | Battery energy storage control and management system | Battery energy storage control and management system used prices |
# |  58 | Battery energy storage control and management system | Battery energy storage control and management system blue book   |
# |  59 | Battery energy storage control and management system | Battery energy storage management system price comparison        |
# |  60 | Battery energy storage control and management system | Battery energy storage systems for sale                          |
# |  61 | Battery energy storage control and management system | Battery energy storage control system pricing                    |
# |  62 | Battery energy storage control and management system | Battery storage systems price directory                          |
# |  63 | Battery energy storage control and management system | Battery energy storage system product catalog                    |
# |  64 | Battery energy storage control and management system | Buy battery energy storage management systems online             |
# |  65 | Battery energy storage control and management system | Battery energy storage systems price quotes                      |
# |  66 | Battery energy storage control and management system | Battery storage management systems pricing information           |
# |  67 | Battery energy storage control and management system | Battery energy storage system listings with prices               |
# |  68 | Battery energy storage control and management system | Battery energy storage systems price comparison tool             |
# |  69 | Battery energy storage control and management system | Buy battery management systems with prices                       |
# |  70 | Battery energy storage control and management system | Battery storage systems for sale online with prices              |
# |  71 | Solar power plants                                   | Solar power plants price list                                    |
# |  72 | Solar power plants                                   | Solar power plants used prices                                   |
# |  73 | Solar power plants                                   | Solar power plants blue book                                     |
# |  74 | Solar power plants                                   | solar power plant pricing guide                                  |
# |  75 | Solar power plants                                   | solar energy system cost comparison                              |
# |  76 | Solar power plants                                   | commercial solar power plant prices                              |
# |  77 | Solar power plants                                   | solar power plant product listings                               |
# |  78 | Solar power plants                                   | solar power plant pricing online                                 |
# |  79 | Solar power plants                                   | solar power plant models with prices                             |
# |  80 | Solar power plants                                   | solar power plant equipment prices                               |
# |  81 | Solar power plants                                   | solar power plant suppliers pricing                              |
# |  82 | Solar power plants                                   | solar power plant cost listings                                  |
# |  83 | Solar power plants                                   | solar power plant price quotes                                   |
# |  84 | Solar power plants                                   | solar power plant equipment price comparison                     |
# |  85 | Solar power plants                                   | solar power plant model pricing directory                        |
# |  86 | General tool kits                                    | General tool kits blue book                                      |
# |  87 | General tool kits                                    | General tool kits used prices                                    |
# |  88 | General tool kits                                    | General tool kits price list                                     |
# |  89 | General tool kits                                    | buy general tool kits online                                     |
# |  90 | General tool kits                                    | general tool kits price comparison                               |
# |  91 | General tool kits                                    | general tool kits for sale                                       |
# |  92 | General tool kits                                    | general tool kits price listings                                 |
# |  93 | General tool kits                                    | buy tool kits online prices                                      |
# |  94 | General tool kits                                    | tool kits e-commerce sites                                       |
# |  95 | Trim or molding tools                                | Trim or molding tools used prices                                |
# |  96 | Trim or molding tools                                | Trim or molding tools blue book                                  |
# |  97 | Trim or molding tools                                | Trim or molding tools price list                                 |
# |  98 | Trim or molding tools                                | Trim molding tools pricing                                       |
# |  99 | Trim or molding tools                                | Buy trim molding tools online                                    |
# | 100 | Trim or molding tools                                | Trim molding tools for sale with prices                          |
# | 101 | Trim or molding tools                                | Trim molding tools price comparison                              |
# | 102 | Trim or molding tools                                | Trim molding tools online store                                  |
# | 103 | Trim or molding tools                                | Buy trim molding tools with prices                               |
# | 104 | Gabion block                                         | Gabion block blue book                                           |
# | 105 | Gabion block                                         | Gabion block used prices                                         |
# | 106 | Gabion block                                         | Gabion block price list                                          |
# | 107 | Gabion block                                         | Gabion block pricing                                             |
# | 108 | Gabion block                                         | Gabion block suppliers                                           |
# | 109 | Gabion block                                         | Gabion block cost comparison                                     |
# | 110 | Gabion block                                         | Gabion block online store                                        |
# | 111 | Gabion block                                         | Gabion block price quotes                                        |
# | 112 | Gabion block                                         | Gabion block product catalog                                     |
# | 113 | Gabion block                                         | Gabion block product prices                                      |
# | 114 | Gabion block                                         | Gabion block suppliers price list                                |
# | 115 | Gabion block                                         | Gabion block e-commerce prices                                   |
# | 116 | Gabion block                                         | Gabion block price comparison site                               |
# | 117 | Gabion block                                         | Gabion block online marketplace                                  |
# | 118 | Gabion block                                         | Buy Gabion block prices                                          |
# | 119 | Toothbrush or tumbler holder                         | Toothbrush or tumbler holder blue book                           |
# | 120 | Toothbrush or tumbler holder                         | Toothbrush holder prices                                         |
# | 121 | Toothbrush or tumbler holder                         | Tumbler holder price list                                        |
# | 122 | Toothbrush or tumbler holder                         | Buy toothbrush and tumbler holders online                        |
# | 123 | Computer server                                      | Computer server blue book                                        |
# | 124 | Computer server                                      | Computer server price list                                       |
# | 125 | Computer server                                      | Computer server used prices                                      |
# | 126 | Computer server                                      | buy computer server online                                       |
# | 127 | Computer server                                      | computer server pricing guide                                    |
# | 128 | Computer server                                      | computer server marketplace                                      |
# | 129 | Computer server                                      | computer server price comparison                                 |
# | 130 | Computer server                                      | buy computer server prices                                       |
# | 131 | Computer server                                      | computer server product listings                                 |
# | 132 | Computer server                                      | computer server price directory                                  |
# | 133 | Computer server                                      | computer server inventory with prices                            |
# | 134 | Computer server                                      | computer server sales listings                                   |
# | 135 | Computer server                                      | computer server price listings                                   |
# | 136 | Computer server                                      | current computer server prices                                   |
# | 137 | Computer server                                      | computer server online catalog                                   |
# | 138 | Notebook computer                                    | Notebook computer blue book                                      |
# | 139 | Notebook computer                                    | Notebook computer price list                                     |
# | 140 | Notebook computer                                    | Notebook computer used prices                                    |
# | 141 | Notebook computer                                    | Notebook computer price comparison                               |
# | 142 | Notebook computer                                    | Buy notebook computers online                                    |
# | 143 | Notebook computer                                    | Notebook laptop pricing guide                                    |
# | 144 | Notebook computer                                    | Notebook computer pricing online                                 |
# | 145 | Notebook computer                                    | Buy notebook laptops with prices                                 |
# | 146 | Notebook computer                                    | Notebook computer price listings                                 |
# | 147 | Notebook computer                                    | Notebook laptop prices                                           |
# | 148 | Notebook computer                                    | Notebook computer sales                                          |
# | 149 | Notebook computer                                    | Buy used notebook laptops                                        |
# | 150 | Desktop computer                                     | Desktop computer blue book                                       |
# | 151 | Desktop computer                                     | Desktop computer price list                                      |
# | 152 | Desktop computer                                     | Desktop computer used prices                                     |
# | 153 | Desktop computer                                     | buy desktop computer prices                                      |
# | 154 | Desktop computer                                     | desktop computer price comparison                                |
# | 155 | Desktop computer                                     | desktop computer listings for sale                               |
# | 156 | Desktop computer                                     | desktop computer sales                                           |
# | 157 | Desktop computer                                     | desktop computer price listings                                  |
# | 158 | Desktop computer                                     | buy desktop computers online                                     |
# | 159 | Personal computer                                    | Personal computer blue book                                      |
# | 160 | Personal computer                                    | Personal computer price list                                     |
# | 161 | Personal computer                                    | Personal computer used prices                                    |
# | 162 | Personal computer                                    | buy personal computer online                                     |
# | 163 | Personal computer                                    | personal computer price comparison                               |
# | 164 | Personal computer                                    | current personal computer listings                               |
# | 165 | Personal computer                                    | personal computer price database                                 |
# | 166 | Personal computer                                    | personal computer sales listings                                 |
# | 167 | Personal computer                                    | buy personal computer prices online                              |
# | 168 | Personal computer                                    | personal computer pricing guide                                  |
# | 169 | Personal computer                                    | buy personal computers online                                    |
# | 170 | Personal computer                                    | personal computer model price list                               |
# | 171 | Personal computer                                    | current personal computer prices                                 |
# | 172 | Personal computer                                    | online personal computer prices                                  |
# | 173 | Personal computer                                    | personal computer price listings                                 |
# | 174 | Photocopiers                                         | Photocopiers price list                                          |
# | 175 | Photocopiers                                         | Photocopiers used prices                                         |
# | 176 | Photocopiers                                         | Photocopiers blue book                                           |
# | 177 | Photocopiers                                         | buy photocopiers online                                          |
# | 178 | Photocopiers                                         | photocopier prices comparison                                    |
# | 179 | Photocopiers                                         | photocopier sales listings                                       |
# | 180 | Multifunction machines                               | Multifunction machines used prices                               |
# | 181 | Multifunction machines                               | Multifunction machines price list                                |
# | 182 | Multifunction machines                               | Multifunction machines blue book                                 |
# | 183 | Multifunction machines                               | buy multifunction machines online                                |
# | 184 | Multifunction machines                               | multifunction machines price comparison                          |
# | 185 | Multifunction machines                               | multifunction printer prices list                                |
# | 186 | Multifunction machines                               | buy multifunction machines                                       |
# | 187 | Multifunction machines                               | multifunction printer price listings                             |
# | 188 | Multifunction machines                               | multifunction machines for sale online                           |
# | 189 | Office product equipment and stationery consumable   | Office product equipment and stationery consumable used prices   |
# | 190 | Office product equipment and stationery consumable   | Office product equipment and stationery consumable price list    |
# | 191 | Office product equipment and stationery consumable   | Office product equipment and stationery consumable blue book     |
# | 192 | Office product equipment and stationery consumable   | Office supplies price comparison                                 |
# | 193 | Office product equipment and stationery consumable   | Office equipment and stationery price listings                   |
# | 194 | Office product equipment and stationery consumable   | Buy office products online with prices                           |
# | 195 | Office product equipment and stationery consumable   | Office supplies prices online                                    |
# | 196 | Office product equipment and stationery consumable   | Stationery products price catalog                                |
# | 197 | Office product equipment and stationery consumable   | Office equipment price listings                                  |
# | 198 | Inkjet printer for commercial printing applications  | Inkjet printer for commercial printing applications blue book    |
# | 199 | Inkjet printer for commercial printing applications  | Inkjet printer for commercial printing applications price list   |
# | 200 | Inkjet printer for commercial printing applications  | Inkjet printer for commercial printing applications used prices  |
# | 201 | Inkjet printer for commercial printing applications  | commercial inkjet printer price comparison                       |
# | 202 | Inkjet printer for commercial printing applications  | buy inkjet printers for commercial use                           |
# | 203 | Inkjet printer for commercial printing applications  | inkjet printer pricing online marketplace                        |
# | 204 | Inkjet printer for commercial printing applications  | commercial inkjet printer price listings                         |
# | 205 | Inkjet printer for commercial printing applications  | buy commercial inkjet printers online                            |
# | 206 | Inkjet printer for commercial printing applications  | inkjet printer prices for business use                           |
# | 207 | Inkjet printer for commercial printing applications  | commercial inkjet printer price directory                        |
# | 208 | Inkjet printer for commercial printing applications  | inkjet printers for business pricing                             |
# | 209 | Inkjet printer for commercial printing applications  | buy commercial inkjet printers online prices                     |
# | 210 | Inkjet printer for commercial printing applications  | commercial inkjet printer online prices                          |
# | 211 | Inkjet printer for commercial printing applications  | inkjet printer sales for businesses                              |
# | 212 | Inkjet printer for commercial printing applications  | purchase commercial inkjet printer models with prices            |
# +-----+------------------------------------------------------+------------------------------------------------------------------+

# %%
# import matplotlib.pyplot as plt

# df = search_term_performace(raw_responses_commodities)

# # Grouping the data by 'commodity' and 'iteration' to aggregate the results
# grouped_data = df.groupby(['commodity', 'iteration'])[['approved_search_results', 'disapproved_search_results']].sum().reset_index()

# # Get the list of unique commodities
# commodities = grouped_data['commodity'].unique()

# for commodity in commodities:
#     # Filter data for the current commodity
#     data = df[df['commodity'] == commodity]

#     # Setting up the figure and axis
#     fig, ax = plt.subplots(figsize=(16, 10))

#     # Initialize variables for x positions and labels
#     x_positions = []
#     x_labels = []
#     current_position = 0

#     # Iterate over each iteration group
#     for iteration in sorted(data['iteration'].unique()):
#         # Filter data for this iteration
#         iteration_data = data[data['iteration'] == iteration]

#         # Define the x positions for this iteration's search terms
#         search_terms = iteration_data['search_term'].values
#         num_terms = len(search_terms)
#         positions = list(range(current_position, current_position + num_terms))

#         # Update x positions and labels
#         x_positions.extend(positions)
#         # Split long search terms into two lines for better readability
#         formatted_labels = [f"Iter {iteration}:\n{term}" if len(term) > 30 else f"Iter {iteration}:\n{term}"
#                             for term in search_terms]
#         x_labels.extend(formatted_labels)

#         # Plot approved and disapproved results
#         ax.bar(
#             positions,
#             iteration_data['approved_search_results'],
#             width=0.4,
#             color='green',
#         )
#         ax.bar(
#             positions,
#             iteration_data['disapproved_search_results'],
#             width=0.4,
#             bottom=iteration_data['approved_search_results'],
#             color='red',
#         )

#         # Update current position for the next iteration
#         current_position += num_terms + 1  # Adding a gap between iterations

#     # Customizing the plot
#     ax.set_xlabel('Search Terms (by Iteration)', fontsize=14)
#     ax.set_ylabel('Count of Results', fontsize=14)
#     ax.set_title(f'Search Term Results for {commodity}', fontsize=16, fontweight='bold')
#     ax.set_xticks(x_positions)
#     ax.set_xticklabels(x_labels, rotation=45, ha='right', fontsize=12)
    
#     # Adding a single legend
#     ax.legend(['Approved', 'Disapproved'], fontsize=12)

#     # Enhancing the plot appearance
#     ax.grid(axis='y', linestyle='--', alpha=0.7)
#     plt.tight_layout()
#     plt.show()
